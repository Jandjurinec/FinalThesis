# %%
from PSO import *
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

if tf.config.list_physical_devices('GPU'):
    print("CUDA is available!")
else:
    print("CUDA is not available.")
# Out:
# 2024-12-15 19:20:15.262138: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734286815.278661  473093 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734286815.282868  473093 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-15 19:20:15.302843: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
bs, cc, ccp = PSO(swarm_size=20, max_iter=30,
            c1=2, c2=1.75, w=0.5,
            is_global_neigh=True) # change to False later, because it can get stuck in local optima
# Out:
# I0000 00:00:1734286819.814363  473093 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5886 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734286821.781973  473195 service.cc:148] XLA service 0x73d87400f710 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734286821.782015  473195 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2024-12-15 19:20:21.815012: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1734286821.902933  473195 cuda_dnn.cc:529] Loaded cuDNN version 90300
# ...

# %%
iterations = np.arange(len(cc))

plt.figure(figsize=(8, 6))
plt.plot(iterations, cc, marker='o', linestyle='-', color='b', label='Objective Value')
plt.grid(visible=True)
plt.xlabel('Iterations')
plt.ylabel('F1')
plt.show()

# %%
iterations = np.arange(len(ccp))

plt.figure(figsize=(8, 6))
plt.plot(iterations, ccp, marker='o', linestyle='-', color='b', label='Objective Value')
plt.grid(visible=True)
plt.xlabel('Iterations')
plt.ylabel('F1')
plt.show()

# %%
bs
# test using these hyperparam on the whole dataset
# Out:
# np.float64(0.926829268292683)
